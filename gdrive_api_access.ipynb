# %%
#!pip install oauth2client
#!pip install PyOpenSSL
#!pip install gspread

# %%
import gspread

# %%
import json
import gspread
from oauth2client.client import SignedJwtAssertionCredentials

json_key = json.load(open('creds.json')) # json credentials you downloaded earlier
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

credentials = SignedJwtAssertionCredentials(json_key['client_email'], json_key['private_key'].encode(), scope) # get email and key from creds

file = gspread.authorize(credentials) # authenticate with Google
sheet = file.open("Stat Badger").sheet1 # open sheet

# %%
all_cells = sheet.range('A1:A10000')

# %%
list_gsow_pages = []

for cell in all_cells:
    if (cell.value != 'Page Name') and (len(cell.value) > 1):
        list_gsow_pages.append(cell.value.strip())

# %%
list_gsow_pages
# Out:
# ['Brian Dunning (author)',
#  'Phil Plait',
#  'Derek Colanduno',
#  'James Alcock',
#  'Ray Hyman',
#  'Robert Sheaffer',
#  'Barry Beyerstein',
#  'Jerry Andrus',
#  'Mark Edward',
#  'Ben Radford',
#  'Committee for Skeptical Inquiry',
#  'James Randi Educational Foundation',
#  'Karen Stollznow',
#  'Ellery Schempp',
#  'Pet psychic',
#  'Vashti McCollum',
#  'James Underdown',
#  'The Steve Allen Theater',
#  'Institute for the Study of Secularism in Society and Culture',
#  'William B. Davis',
#  'Phillip Klass',
#  'Tom Flynn (author)',
#  'Massimo Polidoro',
#  'Mary Roach',
#  'Stan Romanek',
#  'The Amaz!ng Meeting',
#  'Desiree Schell',
#  'SkeptiCamp',
#  'Alison Gopnik',
#  'Sikivu Hutchinson',
#  'Gesellschaft zur wissenschaftlichen Untersuchung von Parawissenschaften (German)',
#  'Skepticality',
#  'Kendrick Frazier',
#  'Robert Ingersoll Birthplace',
#  'Gok van Pascal (Dutch)',
#  'Edwina Rogers',
#  'Andrew A. Skolnick',
#  'Jennifer Ouellette',
# ...
